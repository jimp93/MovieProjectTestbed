# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import numpy as np
import random
import json

# %%
def box_office_1000(url, year):
    col_names=['rank', 'title', 'worldwide $', 'domestic $', 'domestic %', 'foreign $', 'foreign %']
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    container = soup.find('div', class_='a-section imdb-scroll-table-inner')
    tables = container.find('table').findAll('tr')
    for f in range(1,101):
        time.sleep(random.uniform(1, 3))
        film_row = tables[f]
        cols = film_row.findAll('td')
        row_dict={}
        row_dict['year']=year
        c=0
        for col in cols:
            col_name = col_names[c]
            row_dict[col_name] = col.text
            c+=1
        box_office_list.append(row_dict)

# %%
box_office_list = []

def next_year():
    for d in range(10):
        year = 2021 - d
        string_year = str(year)
        base_url = 'https://www.boxofficemojo.com/year/world/'
        url = base_url + string_year + "/"
        box_office_1000(url, string_year)    
        
next_year()
box_office_1000_df = pd.DataFrame(box_office_list)
box_office_1000_df
# Out:
#      year rank                                 title   worldwide $  \
# 0    2021    1                               Hi, Mom  $822,009,764
# 1    2021    2                     F9: The Fast Saga  $714,398,815
# 2    2021    3                 Detective Chinatown 3  $686,257,563
# 3    2021    4                     Godzilla vs. Kong  $467,863,133
# 4    2021    5                           Black Widow  $377,665,240
# ..    ...  ...                                   ...           ...
# 995  2012   96                             The Watch   $68,267,862
# 996  2012   97                      Moonrise Kingdom   $68,263,166
# 997  2012   98                The Secret of the Gods   $67,537,798
# 998  2012   99            Madea's Witness Protection   $66,899,242
# 999  2012  100  Beauty and the Beast 2012 3D Release   $62,767,829
#
#        domestic $ domestic %     foreign $ foreign %
# 0               -          -  $822,009,764      100%
# 1    $172,931,815      24.2%  $541,467,000     75.8%
# 2               -          -  $686,257,563      100%
# 3    $100,563,133      21.5%  $367,300,000     78.5%
# 4    $183,177,333      48.5%  $194,487,907     51.5%
# ..            ...        ...           ...       ...
# 995   $35,353,000      51.8%   $32,914,862     48.2%
# 996   $45,512,466      66.7%   $22,750,700     33.3%
# 997             -          -   $67,537,798      100%
# 998   $65,653,242      98.1%    $1,246,000      1.9%
# 999   $47,617,067      75.9%   $15,150,762     24.1%
#
# [1000 rows x 8 columns]

# %%
box_office_1000_df.dtypes
# Out:
# year           object
# rank           object
# title          object
# worldwide $    object
# domestic $     object
# domestic %     object
# foreign $      object
# foreign %      object
# dtype: object

# %%
bo_1000_clean_df = box_office_1000_df.applymap(lambda x: x[1:].replace(',', '') if  x[0] == "$" else x)
bo_1000_clean_df = bo_1000_clean_df.applymap(lambda x: x[:-1] if  x[-1] == "%" else x)
bo_1000_clean_df
# Out:
#      year rank                                 title worldwide $ domestic $  \
# 0    2021    1                               Hi, Mom   822009764          -
# 1    2021    2                     F9: The Fast Saga   714398815  172931815
# 2    2021    3                 Detective Chinatown 3   686257563          -
# 3    2021    4                     Godzilla vs. Kong   467863133  100563133
# 4    2021    5                           Black Widow   377665240  183177333
# ..    ...  ...                                   ...         ...        ...
# 995  2012   96                             The Watch    68267862   35353000
# 996  2012   97                      Moonrise Kingdom    68263166   45512466
# 997  2012   98                The Secret of the Gods    67537798          -
# 998  2012   99            Madea's Witness Protection    66899242   65653242
# 999  2012  100  Beauty and the Beast 2012 3D Release    62767829   47617067
#
#     domestic %  foreign $ foreign %
# 0            -  822009764       100
# 1         24.2  541467000      75.8
# 2            -  686257563       100
# 3         21.5  367300000      78.5
# 4         48.5  194487907      51.5
# ..         ...        ...       ...
# 995       51.8   32914862      48.2
# 996       66.7   22750700      33.3
# 997          -   67537798       100
# 998       98.1    1246000       1.9
# 999       75.9   15150762      24.1
#
# [1000 rows x 8 columns]

# %%
bo_1000_clean_df = bo_1000_clean_df.applymap(lambda x: '0' if  x == "-" else x)
bo_1000_clean_df.head(1000)
# Out:
#      year rank                                 title worldwide $ domestic $  \
# 0    2021    1                               Hi, Mom   822009764          0
# 1    2021    2                     F9: The Fast Saga   714398815  172931815
# 2    2021    3                 Detective Chinatown 3   686257563          0
# 3    2021    4                     Godzilla vs. Kong   467863133  100563133
# 4    2021    5                           Black Widow   377665240  183177333
# ..    ...  ...                                   ...         ...        ...
# 995  2012   96                             The Watch    68267862   35353000
# 996  2012   97                      Moonrise Kingdom    68263166   45512466
# 997  2012   98                The Secret of the Gods    67537798          0
# 998  2012   99            Madea's Witness Protection    66899242   65653242
# 999  2012  100  Beauty and the Beast 2012 3D Release    62767829   47617067
#
#     domestic %  foreign $ foreign %
# 0            0  822009764       100
# 1         24.2  541467000      75.8
# 2            0  686257563       100
# 3         21.5  367300000      78.5
# 4         48.5  194487907      51.5
# ..         ...        ...       ...
# 995       51.8   32914862      48.2
# 996       66.7   22750700      33.3
# 997          0   67537798       100
# 998       98.1    1246000       1.9
# 999       75.9   15150762      24.1
#
# [1000 rows x 8 columns]

# %%
bo_1000_clean_df[['domestic %', 'foreign %']] = bo_1000_clean_df[['domestic %', 'foreign %']].applymap(lambda x: x[1:] if x[0] == '<' else x)
bo_1000_clean_df.head(1000)
# Out:
#      year rank                                 title worldwide $ domestic $  \
# 0    2021    1                               Hi, Mom   822009764          0
# 1    2021    2                     F9: The Fast Saga   714398815  172931815
# 2    2021    3                 Detective Chinatown 3   686257563          0
# 3    2021    4                     Godzilla vs. Kong   467863133  100563133
# 4    2021    5                           Black Widow   377665240  183177333
# ..    ...  ...                                   ...         ...        ...
# 995  2012   96                             The Watch    68267862   35353000
# 996  2012   97                      Moonrise Kingdom    68263166   45512466
# 997  2012   98                The Secret of the Gods    67537798          0
# 998  2012   99            Madea's Witness Protection    66899242   65653242
# 999  2012  100  Beauty and the Beast 2012 3D Release    62767829   47617067
#
#     domestic %  foreign $ foreign %
# 0            0  822009764       100
# 1         24.2  541467000      75.8
# 2            0  686257563       100
# 3         21.5  367300000      78.5
# 4         48.5  194487907      51.5
# ..         ...        ...       ...
# 995       51.8   32914862      48.2
# 996       66.7   22750700      33.3
# 997          0   67537798       100
# 998       98.1    1246000       1.9
# 999       75.9   15150762      24.1
#
# [1000 rows x 8 columns]

# %%
bo_1000_clean_df[['worldwide $', 'domestic $', 'foreign $', 'domestic %', 'foreign %']] = bo_1000_clean_df[['worldwide $', 'domestic $', 'foreign $', 'domestic %', 'foreign %']].astype(float)
bo_1000_clean_df
# Out:
#      year rank                                 title  worldwide $  \
# 0    2021    1                               Hi, Mom  822009764.0
# 1    2021    2                     F9: The Fast Saga  714398815.0
# 2    2021    3                 Detective Chinatown 3  686257563.0
# 3    2021    4                     Godzilla vs. Kong  467863133.0
# 4    2021    5                           Black Widow  377665240.0
# ..    ...  ...                                   ...          ...
# 995  2012   96                             The Watch   68267862.0
# 996  2012   97                      Moonrise Kingdom   68263166.0
# 997  2012   98                The Secret of the Gods   67537798.0
# 998  2012   99            Madea's Witness Protection   66899242.0
# 999  2012  100  Beauty and the Beast 2012 3D Release   62767829.0
#
#       domestic $  domestic %    foreign $  foreign %
# 0            0.0         0.0  822009764.0      100.0
# 1    172931815.0        24.2  541467000.0       75.8
# 2            0.0         0.0  686257563.0      100.0
# 3    100563133.0        21.5  367300000.0       78.5
# 4    183177333.0        48.5  194487907.0       51.5
# ..           ...         ...          ...        ...
# 995   35353000.0        51.8   32914862.0       48.2
# 996   45512466.0        66.7   22750700.0       33.3
# 997          0.0         0.0   67537798.0      100.0
# 998   65653242.0        98.1    1246000.0        1.9
# 999   47617067.0        75.9   15150762.0       24.1
#
# [1000 rows x 8 columns]

# %%
bo_1000_clean_df.head(1000)
# Out:
#      year rank                                 title  worldwide $  \
# 0    2021    1                               Hi, Mom  822009764.0
# 1    2021    2                     F9: The Fast Saga  714398815.0
# 2    2021    3                 Detective Chinatown 3  686257563.0
# 3    2021    4                     Godzilla vs. Kong  467863133.0
# 4    2021    5                           Black Widow  377665240.0
# ..    ...  ...                                   ...          ...
# 995  2012   96                             The Watch   68267862.0
# 996  2012   97                      Moonrise Kingdom   68263166.0
# 997  2012   98                The Secret of the Gods   67537798.0
# 998  2012   99            Madea's Witness Protection   66899242.0
# 999  2012  100  Beauty and the Beast 2012 3D Release   62767829.0
#
#       domestic $  domestic %    foreign $  foreign %
# 0            0.0         0.0  822009764.0      100.0
# 1    172931815.0        24.2  541467000.0       75.8
# 2            0.0         0.0  686257563.0      100.0
# 3    100563133.0        21.5  367300000.0       78.5
# 4    183177333.0        48.5  194487907.0       51.5
# ..           ...         ...          ...        ...
# 995   35353000.0        51.8   32914862.0       48.2
# 996   45512466.0        66.7   22750700.0       33.3
# 997          0.0         0.0   67537798.0      100.0
# 998   65653242.0        98.1    1246000.0        1.9
# 999   47617067.0        75.9   15150762.0       24.1
#
# [1000 rows x 8 columns]

# %%
bo_1000_clean_df.to_csv('top_1000_bo.csv')

# %%
df = pd.read_csv('top_1000_bo.csv')
df.head(1000)
# Out:
#      Unnamed: 0  year  rank                                 title  \
# 0             0  2021     1                               Hi, Mom
# 1             1  2021     2                     F9: The Fast Saga
# 2             2  2021     3                 Detective Chinatown 3
# 3             3  2021     4                     Godzilla vs. Kong
# 4             4  2021     5                           Black Widow
# ..          ...   ...   ...                                   ...
# 995         995  2012    96                             The Watch
# 996         996  2012    97                      Moonrise Kingdom
# 997         997  2012    98                The Secret of the Gods
# 998         998  2012    99            Madea's Witness Protection
# 999         999  2012   100  Beauty and the Beast 2012 3D Release
#
#      worldwide $   domestic $  domestic %    foreign $  foreign %
# 0    822009764.0          0.0         0.0  822009764.0      100.0
# 1    714398815.0  172931815.0        24.2  541467000.0       75.8
# 2    686257563.0          0.0         0.0  686257563.0      100.0
# 3    467863133.0  100563133.0        21.5  367300000.0       78.5
# 4    377665240.0  183177333.0        48.5  194487907.0       51.5
# ..           ...          ...         ...          ...        ...
# 995   68267862.0   35353000.0        51.8   32914862.0       48.2
# 996   68263166.0   45512466.0        66.7   22750700.0       33.3
# 997   67537798.0          0.0         0.0   67537798.0      100.0
# 998   66899242.0   65653242.0        98.1    1246000.0        1.9
# 999   62767829.0   47617067.0        75.9   15150762.0       24.1
#
# [1000 rows x 9 columns]

# %%
df = df[['title', 'year', 'worldwide $', 'domestic $', 'domestic %', 'foreign $', 'foreign %']]
df
df.to_csv('df.csv')
# Out:
#                                     title  year  worldwide $   domestic $  \
# 0                                 Hi, Mom  2021  822009764.0          0.0
# 1                       F9: The Fast Saga  2021  714398815.0  172931815.0
# 2                   Detective Chinatown 3  2021  686257563.0          0.0
# 3                       Godzilla vs. Kong  2021  467863133.0  100563133.0
# 4                             Black Widow  2021  377665240.0  183177333.0
# ..                                    ...   ...          ...          ...
# 995                             The Watch  2012   68267862.0   35353000.0
# 996                      Moonrise Kingdom  2012   68263166.0   45512466.0
# 997                The Secret of the Gods  2012   67537798.0          0.0
# 998            Madea's Witness Protection  2012   66899242.0   65653242.0
# 999  Beauty and the Beast 2012 3D Release  2012   62767829.0   47617067.0
#
#      domestic %    foreign $  foreign %
# 0           0.0  822009764.0      100.0
# 1          24.2  541467000.0       75.8
# 2           0.0  686257563.0      100.0
# 3          21.5  367300000.0       78.5
# 4          48.5  194487907.0       51.5
# ..          ...          ...        ...
# 995        51.8   32914862.0       48.2
# 996        66.7   22750700.0       33.3
# 997         0.0   67537798.0      100.0
# 998        98.1    1246000.0        1.9
# 999        75.9   15150762.0       24.1
#
# [1000 rows x 7 columns]

# %%
df.to_csv('df.csv')

# %%
english_df = df[df['domestic %'] >= 5]
non_english_df = df[df['domestic %'] <= 5]

# %%
english_df.to_csv('english_df.csv')
non_english_df.to_csv('non_english_df.csv')

# %%
english_df.insert(4, "imdb_code", "No_code")

# %%
english_df.set_index('imdb_code')
# Out:
#                                           title  year  worldwide $  \
# imdb_code
# No_code                       F9: The Fast Saga  2021  714398815.0
# No_code                       Godzilla vs. Kong  2021  467863133.0
# No_code                             Black Widow  2021  377665240.0
# No_code                   A Quiet Place Part II  2021  297372261.0
# No_code                                Free Guy  2021  277748887.0
# ...                                         ...   ...          ...
# No_code                           Anna Karenina  2012   68929150.0
# No_code                               The Watch  2012   68267862.0
# No_code                        Moonrise Kingdom  2012   68263166.0
# No_code              Madea's Witness Protection  2012   66899242.0
# No_code    Beauty and the Beast 2012 3D Release  2012   62767829.0
#
#             domestic $  domestic %    foreign $  foreign %
# imdb_code
# No_code    172931815.0        24.2  541467000.0       75.8
# No_code    100563133.0        21.5  367300000.0       78.5
# No_code    183177333.0        48.5  194487907.0       51.5
# No_code    160072261.0        53.8  137300000.0       46.2
# No_code    102882486.0        37.0  174866401.0       63.0
# ...                ...         ...          ...        ...
# No_code     12816367.0        18.6   56112783.0       81.4
# No_code     35353000.0        51.8   32914862.0       48.2
# No_code     45512466.0        66.7   22750700.0       33.3
# No_code     65653242.0        98.1    1246000.0        1.9
# No_code     47617067.0        75.9   15150762.0       24.1
#
# [724 rows x 7 columns]

# %%
with open('C:/Users/james/.secret/patronOmdb.txt', 'r') as f:
    data = f.read()

# %%
english_df.iloc[0,0]
# Out:
# 'F9: The Fast Saga'

# %%
def url_maker(year, title):
    url = 'http://www.omdbapi.com/?t=' + title + '&y=' + year + '&apikey=' + data
    return url

def title_corrector(title):
    if title == 'F9: The Fast Saga':
        title = 'F9'
    return title

def get_page(url):
    response=requests.get(url)
    movie_data = json.loads(response.content.decode('utf-8')) 
    return movie_data

dud_url=[]
retrieve_error=[]
no_error = []

for m in range(724):
    movie = english_df.iloc[m,0]
    title = movie.replace(',', '%2C').replace (' ', '+').replace (':', '%3A')
    year = str(df.iloc[m,1])
    url = url_maker(year, movie)
    try:
        movie_data = get_page(url)
        if "Error" in movie_data:  
            prev_year = (str(int(year) -1))
            url = url_maker(prev_year, movie)
            movie_data = get_page(url)
            if "Error" in movie_data:
                alt_title = title_corrector(movie)
                url = url_maker(api_year, alt_title)
                movie_data = get_page(url)
                if "Error" in movie_data:
                    film_error = movie + " - " + movie_data_t['Error'] + "\n"
                    retrieve_error.append(prev_film_error)
                else:
                    
                    # add idmb, download the relevant keys 
                    no_error.append(movie)  
            else:
                no_error.append(movie)  
        else:
            no_error.append(movie)
    except:
        dud_url.append(movie)
        
#print(dud_url)
#print(retrieve_error)
#print(no_error)
# Out:
# ['Demon Slayer: Mugen Train', 'Dragon Ball Super: Broly', 'Baahubali 2: The Conclusion', 'The Commuter', 'The Angry Birds Movie', 'Teenage Mutant Ninja Turtles 2: Out of the Shadows', 'The Divergent Series: Insurgent', 'Ride Along 2', 'The 5th Wave', 'Crimson Peak', "Lee Daniels' The Butler", 'Jurassic Park 2013 Re-release', 'Instructions Not Included', 'Scary Movie V', 'Titanic 2012 3D Release', "We're the Millers", 'Last Vegas', 'Walking with Dinosaurs 3D', 'Star Wars: Episode I - The Phantom Menace 2012 3D Release', 'Finding Nemo 2012 3D Release', 'Beauty and the Beast 2012 3D Release']
# []
# ['The Suicide Squad', 'Space Jam: A New Legacy', 'Peter Rabbit 2: The Runaway', 'Tom and Jerry', 'Raya and the Last Dragon', 'The Boss Baby: Family Business', 'Wrath of Man', 'PAW Patrol: The Movie', 'Old', 'Mortal Kombat', 'The Forever Purge', "Hitman's Wife's Bodyguard", 'Candyman', 'Nobody', "Don't Breathe 2", 'Escape Room: Tournament of Champions', 'In the Heights', 'Spirit Untamed', 'Spiral', 'Snake Eyes', 'Nomadland', 'The Unholy', 'The Little Things', 'Respect', 'Chaos Walking', 'The Courier', 'Those Who Wish Me Dead', 'The Marksman', 'Reminiscence', 'The Green Knight', 'Stillwater', 'Minari', 'Malignant', 'The Night House', 'Bad Boys for Life', 'Tenet', 'Sonic the Hedgehog', 'Dolittle', 'The Croods: A New Age', 'Birds of Prey', 'Wonder Woman 1984', 'The Invisible Man', 'Onward', 'The Call of the Wild', 'The New Mutants', 'Fantasy Island', 'Unhinged', 'Monster Hunter', 'Underwater', 'The War with Grandpa', 'Bloodshot', 'Honest Thief', 'Like a Boss', 'Emma.', 'The Father', 'Gretel & Hansel', 'The Photograph', 'Brahms: The Boy II', 'The Turning', 'Promising Young Woman', 'I Still Believe', 'Freaky', 'The Way Back', 'The Personal History of David Copperfield', 'Come Play', 'News of the World', 'Let Him Go', 'The Hunt', 'Avengers: Endgame', 'The Lion King', 'Frozen II', 'Spider-Man: Far from Home', 'Captain Marvel', 'Joker', 'Star Wars: Episode IX - The Rise of Skywalker', 'Toy Story 4', 'Aladdin', 'Jumanji: The Next Level', 'Fast & Furious Presents: Hobbs & Shaw', 'How to Train Your Dragon: The Hidden World', 'Maleficent: Mistress of Evil', 'It Chapter Two', 'Pokémon Detective Pikachu', 'The Secret Life of Pets 2', 'Alita: Battle Angel', 'Godzilla: King of the Monsters', '1917', 'Once Upon a Time... In Hollywood', 'Shazam!', 'Dumbo', 'John Wick: Chapter 3 - Parabellum', 'Knives Out', 'Terminator: Dark Fate', 'Parasite', 'Us', 'Men in Black: International', 'X-Men: Dark Phoenix', 'Glass', 'Annabelle Comes Home', 'Ford v Ferrari', 'Little Women', 'The Addams Family', 'Rocketman', 'Downton Abbey', 'The Lego Movie 2: The Second Part', 'Abominable', 'Gemini Man', 'Spies in Disguise', 'Hustlers', 'Escape Room', 'Yesterday', 'The Angry Birds Movie 2', 'Angel Has Fallen', 'Ad Astra', 'Midway', 'The Upside', 'The Curse of La Llorona', 'Zombieland: Double Tap', 'Last Christmas', 'Dora and the Lost City of Gold', 'Wonder Park', 'The Gentlemen', 'Pet Sematary', 'Good Boys', 'Scary Stories to Tell in the Dark', 'The Hustle', 'Crawl', 'Five Feet Apart', 'Rambo: Last Blood', 'Jojo Rabbit', "A Dog's Way Home", 'Cold Pursuit', "A Dog's Journey", 'A Madea Family Funeral', 'Cats', "Charlie's Angels", 'Doctor Sleep', 'What Men Want', 'After', 'Playing with Fire', 'A Beautiful Day in the Neighborhood', 'War', 'Happy Death Day 2U', 'Avengers: Infinity War', 'Black Panther', 'Jurassic World: Fallen Kingdom', 'Incredibles 2', 'Aquaman', 'Bohemian Rhapsody', 'Venom', 'Mission: Impossible - Fallout', 'Deadpool 2', 'Fantastic Beasts: The Crimes of Grindelwald', 'Ant-Man and the Wasp', 'Ready Player One', 'The Meg', 'Ralph Breaks the Internet', 'Hotel Transylvania 3: Summer Vacation', 'The Grinch', 'Bumblebee', 'A Star Is Born', 'Rampage', 'Mamma Mia! Here We Go Again', 'Solo: A Star Wars Story', 'Spider-Man: Into the Spider-Verse', 'Fifty Shades Freed', 'The Nun', 'Peter Rabbit', 'Mary Poppins Returns', 'A Quiet Place', 'Green Book', 'Skyscraper', "Ocean's Eight", 'Pacific Rim: Uprising', 'Maze Runner: The Death Cure', 'Tomb Raider', 'Halloween', 'Crazy Rich Asians', 'Creed II', 'Smallfoot', 'Christopher Robin', 'The Equalizer 2', 'The Mule', 'The Nutcracker and the Four Realms', 'Insidious: The Last Key', 'The Predator', 'Red Sparrow', 'The First Purge', 'A Wrinkle in Time', 'The House with a Clock in Its Walls', 'Instant Family', 'Game Night', 'First Man', 'Book Club', 'Night School', 'Alpha', 'A Simple Favor', 'The Favourite', 'Truth or Dare', 'I Feel Pretty', 'Blockers', 'BlacKkKlansman', 'Goosebumps 2: Haunted Halloween', 'Overboard', 'Sherlock ...
# ['Chinese Doctors', 'Raging Fire', 'Impasse', "A Writer's Odyssey", 'Sister', 'My Love', 'Detective Conan: The Scarlet Bullet', 'Evangelion: 3.0+1.01 Thrice Upon a Time', 'End Game', 'Boonie Bears: The Wild Life', '1921', 'Avatar 2021 Re-release', 'Nezha Reborn', 'Upcoming', 'Belle: The Dragon and the Freckled Princess', 'Man in Love', 'Break Through the Darkness', 'Luca', 'Love Will Tear Us Apart', 'Tokyo Revengers', 'The Yinyang Master', 'Rurouni Kenshin: Final Chapter Part I - The Final', 'I Fell in Love Like a Flower Bouquet', 'Big Red Envelope', 'Once Upon a Time in Hong Kong', 'Home Sweet Home', 'Master', 'The Last Warrior: Root of Evil', 'Escape from Mogadishu', "My Hero Academia: World Heroes' Mission", 'The Day We Lit Up the Sky', 'Kaamelott: First Installment', 'Rurouni Kenshin: Final Chapter Part II - The Beginning', 'Wish Dragon', 'The Pioneer', 'Mobile Suit Gundam: Hathaway', 'Sinkhole', 'Bo Gia', 'Gintama: The Final', 'The Dry', 'Upon the Magic Roads', 'Something About Love', 'The Tomorrow War', 'Crayon Shin-chan: Shrouded in Mystery! The Flowers of Tenkazu Academy', 'After We Fell', 'Vakeel Saab', 'Monkey King Reborn', 'OSS 117: From Africa with Love', 'No Escapes', 'Hostage: Missing Celebrity', 'Character', 'On Your Mark', 'Stand by Me', 'The Stronghold', "The Fable: The Killer Who Doesn't Kill", 'The Eight Hundred', 'My People, My Homeland', 'Legend of Deification', 'A Little Red Flower', 'Shock Wave 2', 'The Sacrifice', 'Warm Hug', 'Soul', 'Caught in Time', 'The Yin-Yang Master: Dream of Eternity', 'Mulan', 'Stand by Me Doraemon 2', 'The Rescue', 'Love You Forever', 'Greenland', 'Tolo Tolo', 'Vanguard', 'After We Collided', "From Today, It's My Turn: The Movie", 'Trolls World Tour', 'Tanhaji: The Unsung Warrior', 'The End of Endless Love', 'Train to Busan Presents: Peninsula', 'Sarileru Neekevvaru', 'New Interpretation Records of the Three Kingdoms', 'The Confidence Man JP: Princess', 'The Man Standing Next', 'My Mom is a Character 3', "Doraemon the Movie: Nobita's New Dinosaur", 'Deliver Us from Evil', "Harry Potter and the Sorcerer's Stone 2020 Re-release", 'Bath Buddy', 'Ala Vaikunthapurramuloo', 'The Witches', 'Leap', 'Scoob!', 'Interstellar 2020 Re-release', 'Poupelle of Chimney Town', 'Stigmatized Properties', 'Yarn', 'Violet Evergarden: The Movie', 'Ice 2', 'Soul Snatcher', 'Pokémon the Movie: Secrets of the Jungle', "Fate/Stay Night: Heaven's Feel - III. Spring Song", 'Takizawa Enbujo Zero', 'The Promised Neverland', 'Kaiji: Final Game', 'Hitman: Agent Jun', 'Digimon Adventure: Last Evolution Kizuna', 'Bye Bye Morons', 'Baaghi 3', 'Padre no hay más que uno 2: La llegada de la suegra', 'Nightlife', 'Pawn', '#Alive', 'Howling Village', 'Samjin Company English Class', 'Collectors', 'Ducobu 3', 'Legend No. 17', 'Wotakoi: Love Is Hard for Otaku', 'The Voice of Sin', '30 jours max', 'Another Round', 'Ne Zha', 'The Wandering Earth', 'My People, My Country', 'The Captain', 'Crazy Alien', 'Pegasus', 'The Bravest', 'Better Days', 'Weathering with You', 'Sheep Without a Shepherd', 'The White Storm 2: Drug Lords', 'Ip Man 4: The Finale', 'The Climbers', 'Looking Up', 'Extreme Job', 'P Storm', 'Detective Conan: The Fist of Blue Sapphire', 'Boonie Bears: Blast Into the Past', 'Line Walker 2: Invisible Spy', 'The New King of Comedy', 'Adoring', 'One Piece: Stampede', 'Serial (Bad) Weddings 2', 'Exit', 'Eiga Doraemon: Nobita no getsumen tansaki', 'Operation Red Sea', 'Detective Chinatown 2', 'Dying to Survive', 'Hello Mr. Billionaire', 'Monster Hunt 2', 'Us and Them', 'The Island', 'Project Gutenberg', 'Johnny English Strikes Again', 'More Than Blue', 'How Long Will I Love U', 'A Cool Fish', 'The Monkey King 3', 'Detective Conan: Zero the Enforcer', 'Along With the Gods: The Last 49 Days', 'Boonie Bears 5', 'Kill Mobile', 'Shadow', 'Detective Dee: The Four Heavenly Kings', 'Hello, Mrs. Money', 'Hidden Man', 'iPartment the Movie', "Doraemon the Movie: Nobita's Treasure Island", 'Code Blue: The Movie', 'Animal World',  ...

# %%
testeri=requests.get('http://www.omdbapi.com/?i=tt11032374&apikey=727131f3')
print(testeri.content)
# Out:
# b'{"Title":"Kimetsu no Yaiba: Mugen Ressha-Hen","Year":"2020","Rated":"R","Released":"23 Apr 2021","Runtime":"117 min","Genre":"Animation, Action, Adventure","Director":"Haruo Sotozaki","Writer":"Koyoharu Gotouge","Actors":"Natsuki Hanae, Akari Kit\xc3\xb4, Yoshitsugu Matsuoka","Plot":"After his family was brutally murdered and his sister turned into a demon, Tanjiro Kamado\'s journey as a demon slayer began. Tanjiro and his comrades embark on a new mission aboard the Mugen Train, on track to despair.","Language":"Japanese","Country":"Japan","Awards":"3 wins & 3 nominations","Poster":"https://m.media-amazon.com/images/M/MV5BODI2NjdlYWItMTE1ZC00YzI2LTlhZGQtNzE3NzA4MWM0ODYzXkEyXkFqcGdeQXVyNjU1OTg4OTM@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"8.3/10"},{"Source":"Metacritic","Value":"75/100"}],"Metascore":"75","imdbRating":"8.3","imdbVotes":"32,566","imdbID":"tt11032374","Type":"movie","DVD":"N/A","BoxOffice":"$47,700,000","Production":"N/A","Website":"N/A","Response":"True"}'

# %%
testert=requests.get('http://www.omdbapi.com/?t=Impasse&y=2021&apikey=727131f3')
print(testert.content)
# Out:
# b'{"Response":"False","Error":"Movie not found!"}'
